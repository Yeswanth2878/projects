# %% [markdown]
# # project 1
#
# # **Asteroid Dataset EDA**
#
#
# ## Data source location
# From WEB imported as EXCEL:"https://www.kaggle.com/datasets/sakhawat18/asteroid-dataset/data"
# this Dataset all kinds of Data related to Asteroid is included.
#
# ## Data is free to download?
# Yes,it is free to download
#
# ## Data is legal to access?
# Yes, it is legal to access
#
# ## Documented EDA is not available for the data?
# Yes, EDA is not available
#
# ## Size of the data
# The dataset size is 191 MB

# %% [markdown]
# ## Hypothesis:
#
# ### which calss has the highest Asteroid
#
#
# ### Visualizing eccentricity values of Asteroids
#
# ### Top 10 eccentricity Asteroids

# %%
# Import the NumPy library for numerical and mathematical operations
import numpy as npy
# Import the Pandas library for data manipulation and analysis
import pandas as pds

# %%
# Read the 'dataset.csv' file and load its contents into a Pandas DataFrame named 'df'
df=pds.read_csv(r'C:\Users\Yeswanth Sai\Downloads\asteroids\dataset.csv')
# Display the 'df' DataFrame
df
# Out:
# C:\Users\Yeswanth Sai\AppData\Local\Temp\ipykernel_11860\4194986840.py:2: DtypeWarning: Columns (3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pds.read_csv(r'C:\Users\Yeswanth Sai\Downloads\asteroids\dataset.csv')
#               id    spkid          full_name      pdes     name prefix neo  \
# 0       a0000001  2000001            1 Ceres         1    Ceres    NaN   N
# 1       a0000002  2000002           2 Pallas         2   Pallas    NaN   N
# 2       a0000003  2000003             3 Juno         3     Juno    NaN   N
# 3       a0000004  2000004            4 Vesta         4    Vesta    NaN   N
# 4       a0000005  2000005          5 Astraea         5  Astraea    NaN   N
# ...          ...      ...                ...       ...      ...    ...  ..
# 958519  bPLS6013  3246801         (6013 P-L)  6013 P-L      NaN    NaN   N
# 958520  bPLS6331  3246834         (6331 P-L)  6331 P-L      NaN    NaN   N
# ...

# %%
# Get the column names of the DataFrame 'df'
df.columns
# Out:
# Index(['id', 'spkid', 'full_name', 'pdes', 'name', 'prefix', 'neo', 'pha', 'H',
#        'diameter', 'albedo', 'diameter_sigma', 'orbit_id', 'epoch',
#        'epoch_mjd', 'epoch_cal', 'equinox', 'e', 'a', 'q', 'i', 'om', 'w',
#        'ma', 'ad', 'n', 'tp', 'tp_cal', 'per', 'per_y', 'moid', 'moid_ld',
#        'sigma_e', 'sigma_a', 'sigma_q', 'sigma_i', 'sigma_om', 'sigma_w',
#        'sigma_ma', 'sigma_ad', 'sigma_n', 'sigma_tp', 'sigma_per', 'class',
#        'rms'],
#       dtype='object')

# %%
# Display a concise summary of the DataFrame 'df'
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958524 entries, 0 to 958523
# Data columns (total 45 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              958524 non-null  object
#  1   spkid           958524 non-null  int64
#  2   full_name       958524 non-null  object
#  3   pdes            958524 non-null  object
#  4   name            22064 non-null   object
#  5   prefix          18 non-null      object
#  6   neo             958520 non-null  object
#  7   pha             938603 non-null  object
#  8   H               952261 non-null  float64
#  9   diameter        136209 non-null  float64
#  10  albedo          135103 non-null  float64
#  11  diameter_sigma  136081 non-null  float64
#  12  orbit_id        958524 non-null  object
#  13  epoch           958524 non-null  float64
#  14  epoch_mjd       958524 non-null  int64
#  15  epoch_cal       958524 non-null  float64
# ...

# %%
#   display a description of the data in the DataFrame
df.describe()
# Out:
#               spkid              H       diameter         albedo  \
# count  9.585240e+05  952261.000000  136209.000000  135103.000000
# mean   3.810114e+06      16.906411       5.506429       0.130627
# std    6.831541e+06       1.790405       9.425164       0.110323
# min    2.000001e+06      -1.100000       0.002500       0.001000
# 25%    2.239632e+06      16.100000       2.780000       0.053000
# 50%    2.479262e+06      16.900000       3.972000       0.079000
# 75%    3.752518e+06      17.714000       5.765000       0.190000
# max    5.401723e+07      33.200000     939.400000       1.000000
#
#        diameter_sigma         epoch      epoch_mjd     epoch_cal  \
# count   136081.000000  9.585240e+05  958524.000000  9.585240e+05
# mean         0.479184  2.458869e+06   58868.781950  2.019693e+07
# std          0.782895  7.016716e+02     701.671573  1.930354e+04
# min          0.000500  2.425052e+06   25051.000000  1.927062e+07
# ...

# %%
df = df.rename(columns = {
    'e':'Eccentricity',
    'a':'Semi_Major_Axis',
    'q':'Perihelion_Distance',
    'i':'Inclination',
    'M':'Mean_Anomaly',
    'tp': 'Time_of_Perihelion_Passage',
    'n':'Mean_Motion',
    'Q':'Aphelion_Distance',
    'full_name':'Full_Name',
    'spkid':'SPKID',
    'class':'Classification',
    'per':'Period_Days',
    'per_y':'Period_Years'
}).copy()
df.head(10)
# Out:
#          id    SPKID       Full_Name pdes     name prefix neo pha     H  \
# 0  a0000001  2000001         1 Ceres    1    Ceres    NaN   N   N  3.40
# 1  a0000002  2000002        2 Pallas    2   Pallas    NaN   N   N  4.20
# 2  a0000003  2000003          3 Juno    3     Juno    NaN   N   N  5.33
# 3  a0000004  2000004         4 Vesta    4    Vesta    NaN   N   N  3.00
# 4  a0000005  2000005       5 Astraea    5  Astraea    NaN   N   N  6.90
# 5  a0000006  2000006          6 Hebe    6     Hebe    NaN   N   N  5.80
# 6  a0000007  2000007          7 Iris    7     Iris    NaN   N   N  5.60
# 7  a0000008  2000008         8 Flora    8    Flora    NaN   N   N  6.50
# 8  a0000009  2000009         9 Metis    9    Metis    NaN   N   N  6.30
# 9  a0000010  2000010       10 Hygiea   10   Hygiea    NaN   N   N  5.50
#
#    diameter  ...       sigma_i      sigma_om       sigma_w      sigma_ma  \
# 0   939.400  ...  4.608900e-09  6.168800e-08  6.624800e-08  7.820700e-09
# ...

# %%
# Get the index (row labels) of the DataFrame 'df'

df.index
# Out:
# RangeIndex(start=0, stop=958524, step=1)

# %%
# Get the shape of the DataFrame 'df'
df.shape
# Out:
# (958524, 45)

# %%
# Get the data types of columns in the DataFrame 'df'
df.dtypes
# Out:
# id                             object
# SPKID                           int64
# Full_Name                      object
# pdes                           object
# name                           object
# prefix                         object
# neo                            object
# pha                            object
# H                             float64
# diameter                      float64
# albedo                        float64
# diameter_sigma                float64
# orbit_id                       object
# epoch                         float64
# epoch_mjd                       int64
# epoch_cal                     float64
# equinox                        object
# Eccentricity                  float64
# Semi_Major_Axis               float64
# Perihelion_Distance           float64
# Inclination                   float64
# om                            float64
# w                             float64
# ma                            float64
# ad                            float64
# ...

# %%
# get random row from data
df.sample(15)
# Out:
#               id    SPKID            Full_Name        pdes name prefix neo  \
# 535505  a0535506  2535506    535506 (2015 BX5)      535506  NaN    NaN   N
# 474453  a0474454  2474454   474454 (2003 SU41)      474454  NaN    NaN   N
# 863689  bK15X76E  3737174          (2015 XE76)   2015 XE76  NaN    NaN   N
# 623783  bK07Tj8X  3829735         (2007 TX458)  2007 TX458  NaN    NaN   N
# 244410  a0244411  2244411  244411 (2002 PN178)      244411  NaN    NaN   N
# 590645  bK05V09K  3318079           (2005 VK9)    2005 VK9  NaN    NaN   N
# 417518  a0417519  2417519  417519 (2006 SJ334)      417519  NaN    NaN   N
# 856590  bK15TW1B  3736264         (2015 TB321)  2015 TB321  NaN    NaN   N
# 132283  a0132284  2132284   132284 (2002 FX13)      132284  NaN    NaN   N
# 721946  bK12J63A  3848561          (2012 JA63)   2012 JA63  NaN    NaN   N
# 943119  bK18V85Q  3839902          (2018 VQ85)   2018 VQ85  NaN    NaN   N
# ...

# %%
# Assuming 'df' as DataFrame
numeric_columns = df.select_dtypes(include=['number'])  
# This selects only numeric columns

# Calculate the mean along rows
row_mean = numeric_columns.mean(axis=1)

# Print the resulting Series
print(row_mean)
# Out:
# 0         1.352851e+06
# 1         1.353171e+06
# 2         1.353169e+06
# 3         1.352830e+06
# 4         1.353725e+06
#               ...
# 958519    1.480120e+06
# 958520    1.519921e+06
# 958521    1.512651e+06
# 958522    1.488668e+06
# 958523    1.491270e+06
# Length: 958524, dtype: float64

# %%
# Get the number of unique values for each column in the DataFrame 'df'
df.nunique()
# Out:
# id                            958524
# SPKID                         958524
# Full_Name                     958524
# pdes                          958524
# name                           22064
# prefix                             1
# neo                                2
# pha                                2
# H                               9489
# diameter                       16591
# albedo                          1057
# diameter_sigma                  3054
# orbit_id                        4690
# epoch                           5246
# epoch_mjd                       5246
# epoch_cal                       5246
# equinox                            1
# Eccentricity                  958444
# Semi_Major_Axis               958509
# Perihelion_Distance           958509
# Inclination                   958414
# om                            958518
# w                             958519
# ma                            958519
# ad                            958505
# ...

# %%
# Retrieve the last 3 rows of the DataFrame 'df'
df.tail(10)
# Out:
#               id    SPKID          Full_Name      pdes name prefix neo pha  \
# 958514  bPLS2181  3246486         (2181 P-L)  2181 P-L  NaN    NaN   N   N
# 958515  bPLS4198  3246697         (4198 P-L)  4198 P-L  NaN    NaN   N   N
# 958516  bPLS4532  3246735         (4532 P-L)  4532 P-L  NaN    NaN   N   N
# 958517  bPLS4717  3246747         (4717 P-L)  4717 P-L  NaN    NaN   N   N
# 958518  bPLS4847  3246764         (4847 P-L)  4847 P-L  NaN    NaN   N   N
# 958519  bPLS6013  3246801         (6013 P-L)  6013 P-L  NaN    NaN   N   N
# 958520  bPLS6331  3246834         (6331 P-L)  6331 P-L  NaN    NaN   N   N
# 958521  bPLS6344  3013075         (6344 P-L)  6344 P-L  NaN    NaN   Y   Y
# 958522  bT2S2060  3246457         (2060 T-2)  2060 T-2  NaN    NaN   N   N
# 958523  bT3S2678  3246553         (2678 T-3)  2678 T-3  NaN    NaN   N   N
#
#              H  diameter  ...   sigma_i  sigma_om    sigma_w   sigma_ma  \
# ...

# %%
df.values
# Get the underlying NumPy array of values from the DataFrame 'df'
# Out:
# array([['a0000001', 2000001, '     1 Ceres', ..., 9.4159e-09, 'MBA',
#         0.43301],
#        ['a0000002', 2000002, '     2 Pallas', ..., 3.6807e-06, 'MBA',
#         0.35936],
#        ['a0000003', 2000003, '     3 Juno', ..., 3.1072e-06, 'MBA',
#         0.33848],
#        ...,
#        ['bPLS6344', 3013075, '       (6344 P-L)', ..., 9.1275e-05, 'APO',
#         0.51556],
#        ['bT2S2060', 3246457, '       (2060 T-2)', ..., 503.55, 'MBA',
#         0.25641],
#        ['bT3S2678', 3246553, '       (2678 T-3)', ..., 106.48, 'MBA',
#         0.2698]], dtype=object)

# %%
mask=df['prefix'].notnull()
# Create a boolean mask for rows where the 'prefix' column is not null
df[mask]
# Use the mask to filter the DataFrame 'df' and retrieve rows where 'prefix' is not null
# Out:
#               id     SPKID                     Full_Name     pdes       name  \
# 929462  bK17U010   3788040         'Oumuamua (A/2017 U1)  2017 U1  'Oumuamua
# 941727  bK18V030   3836481                   (A/2018 V3)  2018 V3        NaN
# 946609  bK19G020   3841497                   (A/2019 G2)  2019 G2        NaN
# 946632  bK19G030   3841498                   (A/2019 G3)  2019 G3        NaN
# 946657  bK19G040   3841499                   (A/2019 G4)  2019 G4        NaN
# 950538  bK19O020   3843486                   (A/2019 O2)  2019 O2        NaN
# 950563  bK19O030   3843487                   (A/2019 O3)  2019 O3        NaN
# 950588  bK19O040   3843488                   (A/2019 O4)  2019 O4        NaN
# 951748  bK19Q010   3843833                   (A/2019 Q1)  2019 Q1        NaN
# 951773  bK19Q020   3843840                   (A/2019 Q2)  2019 Q2        NaN
# 954907  bK19T010   3879196                   (A/2019 T1)  2019 T1        NaN
# ...

# %% [markdown]
# # Exploratory Analysis and Visualization

# %%
# Import the Seaborn and Matplotlib libraries for data visualization
import seaborn as sns
#import matplotlib
import matplotlib.pyplot as plt
# Display plots directly in the Jupyter Notebook
# %matplotlib inline

# %%
# Randomly select and retrieve a single random row from the DataFrame 'df'
df.sample(1)
# Out:
#               id    SPKID            Full_Name    pdes name prefix neo pha  \
# 434226  a0434227  2434227  434227 (2003 SM235)  434227  NaN    NaN   N   N
#
#            H  diameter  ...  sigma_i  sigma_om   sigma_w  sigma_ma  \
# 434226  16.7       NaN  ...  0.00001  0.000025  0.000044  0.000039
#
#             sigma_ad       sigma_n  sigma_tp  sigma_per  Classification  \
# 434226  3.153900e-08  3.590700e-09  0.000168   0.000024             MBA
#
#             rms
# 434226  0.62318
#
# [1 rows x 45 columns]

# %%
x=df['Classification'].value_counts()
#x=ad.class.value_counts()
x

# Create a bar plot to visualize the distribution of 'x' values with rotated x-axis labels
plt.figure(figsize=(12,6))
# Set the figure size

plt.xticks(rotation=75)
# Rotate x-axis labels for better readability

plt.title("Asteroid Class")
# Set the title of the plot

sns.barplot(x=x.index, y=x);
# Create a bar plot using Seaborn

# %%
x=df.neo.value_counts()
sns.countplot(y=x)
plt.xticks(rotation=75);
plt.title("Asteroid Neo")
plt.ylabel(None);

# %%
df['Eccentricity'].value_counts()
# Out:
# 0.203705    2
# 0.133513    2
# 0.077700    2
# 0.160752    2
# 0.000000    2
#            ..
# 0.205891    1
# 0.225414    1
# 0.154831    1
# 0.142016    1
# 0.258348    1
# Name: Eccentricity, Length: 958444, dtype: int64

# %%
df['Eccentricity'].value_counts() \
    .head(10) \
    .plot(kind='pie', title='Eccentricity of Asteroids')
# Out:
# <AxesSubplot:title={'center':'Eccentricity of Asteroids'}, ylabel='Eccentricity'>

# %%
ax = df['Eccentricity'].value_counts() \
    .head(10) \
    .plot(kind='bar', title='Eccentricity of Top 10 Asteriods')
ax.set_ylabel('Count')
ax.set_xlabel('Eccentricity')
# Out:
# Text(0.5, 0, 'Eccentricity')

# %%
df['Inclination'] \
    .head(10) \
    .plot(kind='kde', title='Inclination of Asteroids')
# Out:
# <AxesSubplot:title={'center':'Inclination of Asteroids'}, ylabel='Density'>
